# %%
import pandas as pd

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

# %%
data['이름']
# Out:
# ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
temp = df['이름']
temp, temp.shape, type(temp)
# Out:
# (0    채치수
#  1    정대만
#  2    송태섭
#  3    서태웅
#  4    강백호
#  5    변덕규
#  6    황태산
#  7    윤대협
#  Name: 이름, dtype: object,
#  (8,),
#  pandas.core.series.Series)

# %% [markdown]
# Series -> 1차원 배열

# %%
temp = df[['이름', '키', '국어']]
temp, type(temp)
# Out:
# (    이름    키   국어
#  0  채치수  197   90
#  1  정대만  184   40
#  2  송태섭  168   80
#  3  서태웅  187   40
#  4  강백호  188   15
#  5  변덕규  202   80
#  6  황태산  188   55
#  7  윤대협  190  100,
#  pandas.core.frame.DataFrame)

# %% [markdown]
# DataFrame -> 2차원 배열

# %%
temp.shape
# Out:
# (8, 3)

# %%
df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.DataFrame(data, columns=['이름', '학교', '키'])
df
# Out:
#     이름   학교    키
# 0  채치수  북산고  197
# 1  정대만  북산고  184
# 2  송태섭  북산고  168
# 3  서태웅  북산고  187
# 4  강백호  북산고  188
# 5  변덕규  능남고  202
# 6  황태산  능남고  188
# 7  윤대협  능남고  190

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object')

# %%
df.index.name = '지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.set_index('이름', inplace=True)
df
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.sort_index(ascending=False)
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 윤대협  능남고  190  100   85   90  95  95          C#
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 변덕규  능남고  202   80  100   95  85  80           C
# 강백호  북산고  188   15   20   10  35  10

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.to_csv('score.csv', encoding='utf-8-sig')

# %%
df.to_csv('score.txt', sep='\t')

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.to_excel('score.xlsx')

# %%
df = pd.read_csv('score.csv', skiprows=1)
df
# Out:
#    1번  채치수  북산고  197   90   85  100  95  85.1      Python
# 0  2번  정대만  북산고  184   40   35   50  55    25        Java
# 1  3번  송태섭  북산고  168   80   75   70  80    75  Javascript
# 2  4번  서태웅  북산고  187   40   60   70  75    80         NaN
# 3  5번  강백호  북산고  188   15   20   10  35    10         NaN
# 4  6번  변덕규  능남고  202   80  100   95  85    80           C
# 5  7번  황태산  능남고  188   55   65   45  40    35      PYTHON
# 6  8번  윤대협  능남고  190  100   85   90  95    95          C#

# %%
df1 = pd.read_csv('시가총액.csv')
df1
# Out:
#      N                  종목명      현재가     전일비     등락률    액면가       시가총액  \
# 0    1                 삼성전자   71,600   1,000  -1.38%    100  4,274,364
# 1    2             LG에너지솔루션  432,500   2,500  +0.58%    500  1,012,050
# 2    3               SK하이닉스  126,600   4,500  -3.43%  5,000    921,651
# 3    4             삼성바이오로직스  711,000   1,000  -0.14%  2,500    506,047
# 4    5                삼성전자우   58,000     700  -1.19%    100    477,274
# 5    6             POSCO홀딩스  472,000   3,000  -0.63%  5,000    399,176
# 6    7                  현대차  181,000     600  -0.33%  5,000    382,872
# 7    8                NAVER  213,500   3,000  +1.43%    100    346,742
# 8    9                   기아   84,200     100  +0.12%  5,000    338,521
# 9   10                 LG화학  472,500     500  -0.11%  5,000    333,549
# 10  11                삼성SDI  442,500   3,000  +0.68%  5,000    304,283
# 11  12               포스코퓨처엠  336,000  12,000  -3.45%    500    260,276
# 12  13                 셀트리온  162,200     400  -0.25%  1,000    237,465
# 13  14                  카카오   50,900     100  +0.20%    100    226,248
# 14  15                 삼성물산  120,600     100  +0.08%    100    223,824
# 15  16                현대모비스  226,000     500  +0.22%  5,000    211,661
# 16  17                 KB금융   51,400     100  -0.19%  5,000    207,405
# 17  18                 신한지주   36,700      50  -0.14%  5,000    189,190
# 18  19                 LG전자  101,800     200  +0.20%  5,000    166,593
# 19  20                 삼성생명   69,400     100  -0.14%    500    138,800
# 20  21              SK이노베이션  136,400     600  +0.44%  5,000    137,294
# 21  22                   LG   82,100     300  -0.36%  5,000    129,144
# 22  23              삼성에스디에스  164,400     700  +0.43%    500    127,209
# 23  24                 한국전력   19,230     100  +0.52%  5,000    123,450
# 24  25                   SK  168,600   1,300  +0.78%    200    123,412
# 25  26               하나금융지주   41,650      50  -0.12%  5,000    121,767
# 26  27                 삼성화재  257,000     500  -0.19%    500    121,753
# 27  28                 KT&G   90,100   1,100  +1.24%  5,000    120,574
# 28  29                카카오뱅크   25,250     150  -0.59%  5,000    120,401
# 29  30              HD현대중공업  133,400     400  -0.30%  5,000    118,423
# 30  31              메리츠금융지주   56,700     700  +1.25%    500    118,060
# 31  32                  HMM   16,290     490  -2.92%  5,000    112,245
# 32  33                SK텔레콤   50,800     200  +0.40%    100    111,167
# 33  34                 고려아연  530,000  12,000  +2.32%  5,000    110,816
# 34  35                 삼성전기  146,600   1,500  +1.03%  5,000    109,501
# 35  36                 크래프톤  212,500   5,500  -2.52%    100    102,771
# 36  37              두산에너빌리티   15,900     290  +1.86%  5,000    101,849
# 37  38               우리금융지주   12,890      20  +0.16%  5,000     96,926
# 38  39             포스코인터내셔널   54,300     600  -1.09%  5,000     95,526
# 39  40                 기업은행   11,840      40  +0.34%  5,000     94,415
# 40  41               에코프로머티  136,500   1,000  -0.73%    500     93,130
# 41  42                  하이브  212,500   3,500  +1.67%    500     88,511
# 42  43                   KT   34,100     500  +1.49%  5,000     87,931
# 43  44                 대한항공   22,600       0   0.00%  5,000     83,218
# 44  45             HD한국조선해양  114,700     200  +0.17%  5,000     81,177
# 45  46                 한화오션   25,900   1,050  -3.90%  5,000     79,347
# 46  47                S-Oil   68,900     200  -0.29%  2,500     77,570
# 47  48               아모레퍼시픽  129,800   2,600  +2.04%    500     75,924
# 48  49  TIGER CD금리투자KIS(합성)   53,430       0   0.00%      0     75,253
# 49  50                삼성중공업    8,160      20  +0.25%  1,000     71,808
#
#         상장주식수  외국인비율        거래량     PER     ROE  토론실
# 0   5,969,783  53.61  4,728,607   15.22   17.07  NaN
# 1     234,000   4.53     74,428   66.52    5.75  NaN
# 2     728,002  52.83  2,047,529   -8.03    3.56  NaN
# 3      71,174  10.20     12,029   54.01   11.42  NaN
# 4     822,887  72.79    467,953   12.33     NaN  NaN
# 5      84,571  26.48    216,233   32.23    6.11  NaN
# 6     211,532  32.88    125,227    4.35    9.36  NaN
# 7     162,409  47.54    457,576   41.34    3.29  NaN
# 8     402,044  38.63    265,152    3.70   14.57  NaN
# 9      70,592  43.09    104,302   28.39    6.95  NaN
# 10     68,765  45.08     81,138   14.73   12.52  NaN
# 11     77,463   5.65    729,567  321.84    4.87  NaN
# 12    146,403  20.42     93,346   39.31   13.35  NaN
# 13    444,496  26.08    523,557  519.39   13.54  NaN
# 14    185,592  19.34     41,878    9.84    7.16  NaN
# 15     93,655  38.67     27,872    6.24    6.80  NaN
# 16    403,511  72.34    232,498    4.41    9.17  NaN
# 17    515,504  60.13    249,386    4.64    9.70  NaN
# 18    163,648  29.11    152,762   27.36    6.61  NaN
# 19    200,000  16.82     30,909    5.55    5.73  NaN
# 20    100,656  21.37     86,815  -55.22    8.49  NaN
# 21    157,301  36.27     45,283   12.38    8.48  NaN
# 22     77,378  16.18     49,272   15.99   14.23  NaN
# 23    641,964  13.92    379,658   -0.89  -46.91  NaN
# 24     73,198  22.78     43,658  -15.78    5.13  NaN
# 25    292,357  68.93    137,898    3.34   10.06  NaN
# 26     47,375  53.44     17,079    7.13    9.70  NaN
# 27    133,822  42.23    107,483   16.87   11.00  NaN
# 28    476,837  15.51    236,828   35.41    4.68  NaN
# 29     88,773   7.29     52,713  -70.43   -6.47  NaN
# 30    208,218  16.85     93,430    5.24   30.32  NaN
# 31    689,039   9.08  1,204,099    3.76   64.98  NaN
# 32    218,833  41.77    170,397    9.84    7.97  NaN
# 33     20,909  18.29     24,545   17.72    9.38  NaN
# 34     74,694  30.53     86,412   23.14   13.76  NaN
# 35     48,363  32.41     34,940   23.47   10.29  NaN
# 36    640,561  13.30  1,620,864  -23.77  -11.70  NaN
# 37    751,949  37.65    319,886    3.24   11.51  NaN
# 38    175,923   6.42    304,082   12.68   15.79  NaN
# 39    797,426  14.06    224,257    3.29    9.85  NaN
# 40     68,227   0.60    967,687  464.29    6.77  NaN
# 41     41,652  20.67     92,871  114.80    1.87  NaN
# 42    257,861  42.80    528,380    7.42    7.99  NaN
# 43    368,221  16.30    173,623    6.19   21.95  NaN
# 44     70,773  25.42     68,383   53.98   -2.22  NaN
# 45    306,359   9.96    899,929   -8.06 -117.79  NaN
# 46    112,583  76.85     52,190    7.90   27.20  NaN
# 47     58,493  27.19     48,491   55.66    2.81  NaN
# 48    140,844   0.02     77,543     NaN     NaN  NaN
# 49    880,000  19.90  1,327,918  -35.02  -16.08  NaN

# %%
del df1['토론실']
df1
# Out:
#      N                  종목명      현재가     전일비     등락률    액면가       시가총액  \
# 0    1                 삼성전자   71,600   1,000  -1.38%    100  4,274,364
# 1    2             LG에너지솔루션  432,500   2,500  +0.58%    500  1,012,050
# 2    3               SK하이닉스  126,600   4,500  -3.43%  5,000    921,651
# 3    4             삼성바이오로직스  711,000   1,000  -0.14%  2,500    506,047
# 4    5                삼성전자우   58,000     700  -1.19%    100    477,274
# 5    6             POSCO홀딩스  472,000   3,000  -0.63%  5,000    399,176
# 6    7                  현대차  181,000     600  -0.33%  5,000    382,872
# 7    8                NAVER  213,500   3,000  +1.43%    100    346,742
# 8    9                   기아   84,200     100  +0.12%  5,000    338,521
# 9   10                 LG화학  472,500     500  -0.11%  5,000    333,549
# 10  11                삼성SDI  442,500   3,000  +0.68%  5,000    304,283
# 11  12               포스코퓨처엠  336,000  12,000  -3.45%    500    260,276
# 12  13                 셀트리온  162,200     400  -0.25%  1,000    237,465
# 13  14                  카카오   50,900     100  +0.20%    100    226,248
# 14  15                 삼성물산  120,600     100  +0.08%    100    223,824
# 15  16                현대모비스  226,000     500  +0.22%  5,000    211,661
# 16  17                 KB금융   51,400     100  -0.19%  5,000    207,405
# 17  18                 신한지주   36,700      50  -0.14%  5,000    189,190
# 18  19                 LG전자  101,800     200  +0.20%  5,000    166,593
# 19  20                 삼성생명   69,400     100  -0.14%    500    138,800
# 20  21              SK이노베이션  136,400     600  +0.44%  5,000    137,294
# 21  22                   LG   82,100     300  -0.36%  5,000    129,144
# 22  23              삼성에스디에스  164,400     700  +0.43%    500    127,209
# 23  24                 한국전력   19,230     100  +0.52%  5,000    123,450
# 24  25                   SK  168,600   1,300  +0.78%    200    123,412
# 25  26               하나금융지주   41,650      50  -0.12%  5,000    121,767
# 26  27                 삼성화재  257,000     500  -0.19%    500    121,753
# 27  28                 KT&G   90,100   1,100  +1.24%  5,000    120,574
# 28  29                카카오뱅크   25,250     150  -0.59%  5,000    120,401
# 29  30              HD현대중공업  133,400     400  -0.30%  5,000    118,423
# 30  31              메리츠금융지주   56,700     700  +1.25%    500    118,060
# 31  32                  HMM   16,290     490  -2.92%  5,000    112,245
# 32  33                SK텔레콤   50,800     200  +0.40%    100    111,167
# 33  34                 고려아연  530,000  12,000  +2.32%  5,000    110,816
# 34  35                 삼성전기  146,600   1,500  +1.03%  5,000    109,501
# 35  36                 크래프톤  212,500   5,500  -2.52%    100    102,771
# 36  37              두산에너빌리티   15,900     290  +1.86%  5,000    101,849
# 37  38               우리금융지주   12,890      20  +0.16%  5,000     96,926
# 38  39             포스코인터내셔널   54,300     600  -1.09%  5,000     95,526
# 39  40                 기업은행   11,840      40  +0.34%  5,000     94,415
# 40  41               에코프로머티  136,500   1,000  -0.73%    500     93,130
# 41  42                  하이브  212,500   3,500  +1.67%    500     88,511
# 42  43                   KT   34,100     500  +1.49%  5,000     87,931
# 43  44                 대한항공   22,600       0   0.00%  5,000     83,218
# 44  45             HD한국조선해양  114,700     200  +0.17%  5,000     81,177
# 45  46                 한화오션   25,900   1,050  -3.90%  5,000     79,347
# 46  47                S-Oil   68,900     200  -0.29%  2,500     77,570
# 47  48               아모레퍼시픽  129,800   2,600  +2.04%    500     75,924
# 48  49  TIGER CD금리투자KIS(합성)   53,430       0   0.00%      0     75,253
# 49  50                삼성중공업    8,160      20  +0.25%  1,000     71,808
#
#         상장주식수  외국인비율        거래량     PER     ROE
# 0   5,969,783  53.61  4,728,607   15.22   17.07
# 1     234,000   4.53     74,428   66.52    5.75
# 2     728,002  52.83  2,047,529   -8.03    3.56
# 3      71,174  10.20     12,029   54.01   11.42
# 4     822,887  72.79    467,953   12.33     NaN
# 5      84,571  26.48    216,233   32.23    6.11
# 6     211,532  32.88    125,227    4.35    9.36
# 7     162,409  47.54    457,576   41.34    3.29
# 8     402,044  38.63    265,152    3.70   14.57
# 9      70,592  43.09    104,302   28.39    6.95
# 10     68,765  45.08     81,138   14.73   12.52
# 11     77,463   5.65    729,567  321.84    4.87
# 12    146,403  20.42     93,346   39.31   13.35
# 13    444,496  26.08    523,557  519.39   13.54
# 14    185,592  19.34     41,878    9.84    7.16
# 15     93,655  38.67     27,872    6.24    6.80
# 16    403,511  72.34    232,498    4.41    9.17
# 17    515,504  60.13    249,386    4.64    9.70
# 18    163,648  29.11    152,762   27.36    6.61
# 19    200,000  16.82     30,909    5.55    5.73
# 20    100,656  21.37     86,815  -55.22    8.49
# 21    157,301  36.27     45,283   12.38    8.48
# 22     77,378  16.18     49,272   15.99   14.23
# 23    641,964  13.92    379,658   -0.89  -46.91
# 24     73,198  22.78     43,658  -15.78    5.13
# 25    292,357  68.93    137,898    3.34   10.06
# 26     47,375  53.44     17,079    7.13    9.70
# 27    133,822  42.23    107,483   16.87   11.00
# 28    476,837  15.51    236,828   35.41    4.68
# 29     88,773   7.29     52,713  -70.43   -6.47
# 30    208,218  16.85     93,430    5.24   30.32
# 31    689,039   9.08  1,204,099    3.76   64.98
# 32    218,833  41.77    170,397    9.84    7.97
# 33     20,909  18.29     24,545   17.72    9.38
# 34     74,694  30.53     86,412   23.14   13.76
# 35     48,363  32.41     34,940   23.47   10.29
# 36    640,561  13.30  1,620,864  -23.77  -11.70
# 37    751,949  37.65    319,886    3.24   11.51
# 38    175,923   6.42    304,082   12.68   15.79
# 39    797,426  14.06    224,257    3.29    9.85
# 40     68,227   0.60    967,687  464.29    6.77
# 41     41,652  20.67     92,871  114.80    1.87
# 42    257,861  42.80    528,380    7.42    7.99
# 43    368,221  16.30    173,623    6.19   21.95
# 44     70,773  25.42     68,383   53.98   -2.22
# 45    306,359   9.96    899,929   -8.06 -117.79
# 46    112,583  76.85     52,190    7.90   27.20
# 47     58,493  27.19     48,491   55.66    2.81
# 48    140,844   0.02     77,543     NaN     NaN
# 49    880,000  19.90  1,327,918  -35.02  -16.08

# %%
df = pd.read_csv('score.csv')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.describe()
# Out:
#                 키          국어          영어          수학         과학         사회
# count    8.000000    8.000000    8.000000    8.000000   8.000000   8.000000
# mean   188.000000   62.500000   65.625000   66.250000  70.000000  60.625000
# std      9.985704   29.519969   26.917533   30.325614  23.754699  32.120032
# min    168.000000   15.000000   20.000000   10.000000  35.000000  10.000000
# 25%    186.250000   40.000000   53.750000   48.750000  51.250000  32.500000
# 50%    188.000000   67.500000   70.000000   70.000000  77.500000  77.500000
# 75%    191.750000   82.500000   85.000000   91.250000  87.500000  81.250000
# max    202.000000  100.000000  100.000000  100.000000  95.000000  95.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지원번호    8 non-null      object
#  1   이름      8 non-null      object
#  2   학교      8 non-null      object
#  3   키       8 non-null      int64
#  4   국어      8 non-null      int64
#  5   영어      8 non-null      int64
#  6   수학      8 non-null      int64
#  7   과학      8 non-null      int64
#  8   사회      8 non-null      int64
#  9   SW특기    6 non-null      object
# dtypes: int64(6), object(4)
# memory usage: 772.0+ bytes

# %%
df.head()
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85      Python
# 1   2번  정대만  북산고  184  40  35   50  55  25        Java
# 2   3번  송태섭  북산고  168  80  75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187  40  60   70  75  80         NaN
# 4   5번  강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.tail()
# Out:
#   지원번호   이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 3   4번  서태웅  북산고  187   40   60  70  75  80     NaN
# 4   5번  강백호  북산고  188   15   20  10  35  10     NaN
# 5   6번  변덕규  능남고  202   80  100  95  85  80       C
# 6   7번  황태산  능남고  188   55   65  45  40  35  PYTHON
# 7   8번  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df.values
# Out:
# array([['1번', '채치수', '북산고', 197, 90, 85, 100, 95, 85, 'Python'],
#        ['2번', '정대만', '북산고', 184, 40, 35, 50, 55, 25, 'Java'],
#        ['3번', '송태섭', '북산고', 168, 80, 75, 70, 80, 75, 'Javascript'],
#        ['4번', '서태웅', '북산고', 187, 40, 60, 70, 75, 80, nan],
#        ['5번', '강백호', '북산고', 188, 15, 20, 10, 35, 10, nan],
#        ['6번', '변덕규', '능남고', 202, 80, 100, 95, 85, 80, 'C'],
#        ['7번', '황태산', '능남고', 188, 55, 65, 45, 40, 35, 'PYTHON'],
#        ['8번', '윤대협', '능남고', 190, 100, 85, 90, 95, 95, 'C#']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.columns
# Out:
# Index(['지원번호', '이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.shape
# Out:
# (8, 10)

# %%
df['키'].describe()
# Out:
# count      8.000000
# mean     188.000000
# std        9.985704
# min      168.000000
# 25%      186.250000
# 50%      188.000000
# 75%      191.750000
# max      202.000000
# Name: 키, dtype: float64

# %%
df['키'].min(), df['키'].max()
# Out:
# (168, 202)

# %%
df['키'].nlargest(3)
# Out:
# 5    202
# 0    197
# 7    190
# Name: 키, dtype: int64

# %%
df['키'].mean()
# Out:
# 188.0

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['SW특기'].count()
# Out:
# 6

# %%
df['학교'].unique(), df['학교'].nunique()
# Out:
# (array(['북산고', '능남고'], dtype=object), 2)

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['이름']
# Out:
# 0    채치수
# 1    정대만
# 2    송태섭
# 3    서태웅
# 4    강백호
# 5    변덕규
# 6    황태산
# 7    윤대협
# Name: 이름, dtype: object

# %%
df[['이름', '키']]
# Out:
#     이름    키
# 0  채치수  197
# 1  정대만  184
# 2  송태섭  168
# 3  서태웅  187
# 4  강백호  188
# 5  변덕규  202
# 6  황태산  188
# 7  윤대협  190

# %%
df[['이름', '키']][:5]
# Out:
#     이름    키
# 0  채치수  197
# 1  정대만  184
# 2  송태섭  168
# 3  서태웅  187
# 4  강백호  188

# %%
df[3:]
# Out:
#   지원번호   이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 3   4번  서태웅  북산고  187   40   60  70  75  80     NaN
# 4   5번  강백호  북산고  188   15   20  10  35  10     NaN
# 5   6번  변덕규  능남고  202   80  100  95  85  80       C
# 6   7번  황태산  능남고  188   55   65  45  40  35  PYTHON
# 7   8번  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df[:3]
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85      Python
# 1   2번  정대만  북산고  184  40  35   50  55  25        Java
# 2   3번  송태섭  북산고  168  80  75   70  80  75  Javascript

# %%
df.loc[0]
# Out:
# 지원번호        1번
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 0, dtype: object

# %%
df = pd.read_csv('score.csv', index_col='지원번호')

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.loc['1번']
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
df.loc['1번', '국어']
# Out:
# 90

# %%
temp = df.loc[['1번', '2번'], '국어']
temp, type(temp)
# Out:
# (지원번호
#  1번    90
#  2번    40
#  Name: 국어, dtype: int64,
#  pandas.core.series.Series)

# %%
temp = df.loc[['1번', '2번'], ['국어', '영어']]
temp, type(temp)
# Out:
# (      국어  영어
#  지원번호
#  1번    90  85
#  2번    40  35,
#  pandas.core.frame.DataFrame)

# %%
df.iloc[0]
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
df.iloc[0:5]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.iloc[0, 1]
# Out:
# '북산고'

# %%
df.iloc[[0,1], [0,1]]
# Out:
#        이름   학교
# 지원번호
# 1번    채치수  북산고
# 2번    정대만  북산고

# %%
df.iloc[0:2, 0:2]
# Out:
#        이름   학교
# 지원번호
# 1번    채치수  북산고
# 2번    정대만  북산고

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df1 = df

# %%
df1
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df1 = pd.read_csv('시가총액.csv')
df1
# Out:
#      N                  종목명      현재가     전일비     등락률    액면가       시가총액  \
# 0    1                 삼성전자   71,600   1,000  -1.38%    100  4,274,364
# 1    2             LG에너지솔루션  432,500   2,500  +0.58%    500  1,012,050
# 2    3               SK하이닉스  126,600   4,500  -3.43%  5,000    921,651
# 3    4             삼성바이오로직스  711,000   1,000  -0.14%  2,500    506,047
# 4    5                삼성전자우   58,000     700  -1.19%    100    477,274
# 5    6             POSCO홀딩스  472,000   3,000  -0.63%  5,000    399,176
# 6    7                  현대차  181,000     600  -0.33%  5,000    382,872
# 7    8                NAVER  213,500   3,000  +1.43%    100    346,742
# 8    9                   기아   84,200     100  +0.12%  5,000    338,521
# 9   10                 LG화학  472,500     500  -0.11%  5,000    333,549
# 10  11                삼성SDI  442,500   3,000  +0.68%  5,000    304,283
# 11  12               포스코퓨처엠  336,000  12,000  -3.45%    500    260,276
# 12  13                 셀트리온  162,200     400  -0.25%  1,000    237,465
# 13  14                  카카오   50,900     100  +0.20%    100    226,248
# 14  15                 삼성물산  120,600     100  +0.08%    100    223,824
# 15  16                현대모비스  226,000     500  +0.22%  5,000    211,661
# 16  17                 KB금융   51,400     100  -0.19%  5,000    207,405
# 17  18                 신한지주   36,700      50  -0.14%  5,000    189,190
# 18  19                 LG전자  101,800     200  +0.20%  5,000    166,593
# 19  20                 삼성생명   69,400     100  -0.14%    500    138,800
# 20  21              SK이노베이션  136,400     600  +0.44%  5,000    137,294
# 21  22                   LG   82,100     300  -0.36%  5,000    129,144
# 22  23              삼성에스디에스  164,400     700  +0.43%    500    127,209
# 23  24                 한국전력   19,230     100  +0.52%  5,000    123,450
# 24  25                   SK  168,600   1,300  +0.78%    200    123,412
# 25  26               하나금융지주   41,650      50  -0.12%  5,000    121,767
# 26  27                 삼성화재  257,000     500  -0.19%    500    121,753
# 27  28                 KT&G   90,100   1,100  +1.24%  5,000    120,574
# 28  29                카카오뱅크   25,250     150  -0.59%  5,000    120,401
# 29  30              HD현대중공업  133,400     400  -0.30%  5,000    118,423
# 30  31              메리츠금융지주   56,700     700  +1.25%    500    118,060
# 31  32                  HMM   16,290     490  -2.92%  5,000    112,245
# 32  33                SK텔레콤   50,800     200  +0.40%    100    111,167
# 33  34                 고려아연  530,000  12,000  +2.32%  5,000    110,816
# 34  35                 삼성전기  146,600   1,500  +1.03%  5,000    109,501
# 35  36                 크래프톤  212,500   5,500  -2.52%    100    102,771
# 36  37              두산에너빌리티   15,900     290  +1.86%  5,000    101,849
# 37  38               우리금융지주   12,890      20  +0.16%  5,000     96,926
# 38  39             포스코인터내셔널   54,300     600  -1.09%  5,000     95,526
# 39  40                 기업은행   11,840      40  +0.34%  5,000     94,415
# 40  41               에코프로머티  136,500   1,000  -0.73%    500     93,130
# 41  42                  하이브  212,500   3,500  +1.67%    500     88,511
# 42  43                   KT   34,100     500  +1.49%  5,000     87,931
# 43  44                 대한항공   22,600       0   0.00%  5,000     83,218
# 44  45             HD한국조선해양  114,700     200  +0.17%  5,000     81,177
# 45  46                 한화오션   25,900   1,050  -3.90%  5,000     79,347
# 46  47                S-Oil   68,900     200  -0.29%  2,500     77,570
# 47  48               아모레퍼시픽  129,800   2,600  +2.04%    500     75,924
# 48  49  TIGER CD금리투자KIS(합성)   53,430       0   0.00%      0     75,253
# 49  50                삼성중공업    8,160      20  +0.25%  1,000     71,808
#
#         상장주식수  외국인비율        거래량     PER     ROE  토론실
# 0   5,969,783  53.61  4,728,607   15.22   17.07  NaN
# 1     234,000   4.53     74,428   66.52    5.75  NaN
# 2     728,002  52.83  2,047,529   -8.03    3.56  NaN
# 3      71,174  10.20     12,029   54.01   11.42  NaN
# 4     822,887  72.79    467,953   12.33     NaN  NaN
# 5      84,571  26.48    216,233   32.23    6.11  NaN
# 6     211,532  32.88    125,227    4.35    9.36  NaN
# 7     162,409  47.54    457,576   41.34    3.29  NaN
# 8     402,044  38.63    265,152    3.70   14.57  NaN
# 9      70,592  43.09    104,302   28.39    6.95  NaN
# 10     68,765  45.08     81,138   14.73   12.52  NaN
# 11     77,463   5.65    729,567  321.84    4.87  NaN
# 12    146,403  20.42     93,346   39.31   13.35  NaN
# 13    444,496  26.08    523,557  519.39   13.54  NaN
# 14    185,592  19.34     41,878    9.84    7.16  NaN
# 15     93,655  38.67     27,872    6.24    6.80  NaN
# 16    403,511  72.34    232,498    4.41    9.17  NaN
# 17    515,504  60.13    249,386    4.64    9.70  NaN
# 18    163,648  29.11    152,762   27.36    6.61  NaN
# 19    200,000  16.82     30,909    5.55    5.73  NaN
# 20    100,656  21.37     86,815  -55.22    8.49  NaN
# 21    157,301  36.27     45,283   12.38    8.48  NaN
# 22     77,378  16.18     49,272   15.99   14.23  NaN
# 23    641,964  13.92    379,658   -0.89  -46.91  NaN
# 24     73,198  22.78     43,658  -15.78    5.13  NaN
# 25    292,357  68.93    137,898    3.34   10.06  NaN
# 26     47,375  53.44     17,079    7.13    9.70  NaN
# 27    133,822  42.23    107,483   16.87   11.00  NaN
# 28    476,837  15.51    236,828   35.41    4.68  NaN
# 29     88,773   7.29     52,713  -70.43   -6.47  NaN
# 30    208,218  16.85     93,430    5.24   30.32  NaN
# 31    689,039   9.08  1,204,099    3.76   64.98  NaN
# 32    218,833  41.77    170,397    9.84    7.97  NaN
# 33     20,909  18.29     24,545   17.72    9.38  NaN
# 34     74,694  30.53     86,412   23.14   13.76  NaN
# 35     48,363  32.41     34,940   23.47   10.29  NaN
# 36    640,561  13.30  1,620,864  -23.77  -11.70  NaN
# 37    751,949  37.65    319,886    3.24   11.51  NaN
# 38    175,923   6.42    304,082   12.68   15.79  NaN
# 39    797,426  14.06    224,257    3.29    9.85  NaN
# 40     68,227   0.60    967,687  464.29    6.77  NaN
# 41     41,652  20.67     92,871  114.80    1.87  NaN
# 42    257,861  42.80    528,380    7.42    7.99  NaN
# 43    368,221  16.30    173,623    6.19   21.95  NaN
# 44     70,773  25.42     68,383   53.98   -2.22  NaN
# 45    306,359   9.96    899,929   -8.06 -117.79  NaN
# 46    112,583  76.85     52,190    7.90   27.20  NaN
# 47     58,493  27.19     48,491   55.66    2.81  NaN
# 48    140,844   0.02     77,543     NaN     NaN  NaN
# 49    880,000  19.90  1,327,918  -35.02  -16.08  NaN

# %%
filter = df['키'] >= 185
df[filter]
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85  Python
# 4번    서태웅  북산고  187   40   60   70  75  80     NaN
# 5번    강백호  북산고  188   15   20   10  35  10     NaN
# 6번    변덕규  능남고  202   80  100   95  85  80       C
# 7번    황태산  능남고  188   55   65   45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95      C#

# %%
df[~filter]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    정대만  북산고  184  40  35  50  55  25        Java
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
df.loc[df['키']>=185, ['이름', '국어', '영어', '수학']]
# Out:
#        이름   국어   영어   수학
# 지원번호
# 1번    채치수   90   85  100
# 4번    서태웅   40   60   70
# 5번    강백호   15   20   10
# 6번    변덕규   80  100   95
# 7번    황태산   55   65   45
# 8번    윤대협  100   85   90

# %%
df.loc[(df['키']>=185) & (df['학교']=='북산고'), ['이름', '국어']]
# Out:
#        이름  국어
# 지원번호
# 1번    채치수  90
# 4번    서태웅  40
# 5번    강백호  15

# %%
filt = df['이름'].str.startswith('송')
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
filt = df['이름'].str.contains('태')
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60  70  75  80         NaN
# 7번    황태산  능남고  188  55  65  45  40  35      PYTHON

# %%
lans=['python', 'java']
filt = df['SW특기'].str.lower().isin(lans)
df[filt]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85  Python
# 2번    정대만  북산고  184  40  35   50  55  25    Java
# 7번    황태산  능남고  188  55  65   45  40  35  PYTHON

# %%
df['SW특기'].str.upper()
# Out:
# 지원번호
# 1번        PYTHON
# 2번          JAVA
# 3번    JAVASCRIPT
# 4번           NaN
# 5번           NaN
# 6번             C
# 7번        PYTHON
# 8번            C#
# Name: SW특기, dtype: object

# %%
df1.iloc[:,:-1]
# Out:
#      N                  종목명      현재가     전일비     등락률    액면가       시가총액  \
# 0    1                 삼성전자   71,600   1,000  -1.38%    100  4,274,364
# 1    2             LG에너지솔루션  432,500   2,500  +0.58%    500  1,012,050
# 2    3               SK하이닉스  126,600   4,500  -3.43%  5,000    921,651
# 3    4             삼성바이오로직스  711,000   1,000  -0.14%  2,500    506,047
# 4    5                삼성전자우   58,000     700  -1.19%    100    477,274
# 5    6             POSCO홀딩스  472,000   3,000  -0.63%  5,000    399,176
# 6    7                  현대차  181,000     600  -0.33%  5,000    382,872
# 7    8                NAVER  213,500   3,000  +1.43%    100    346,742
# 8    9                   기아   84,200     100  +0.12%  5,000    338,521
# 9   10                 LG화학  472,500     500  -0.11%  5,000    333,549
# 10  11                삼성SDI  442,500   3,000  +0.68%  5,000    304,283
# 11  12               포스코퓨처엠  336,000  12,000  -3.45%    500    260,276
# 12  13                 셀트리온  162,200     400  -0.25%  1,000    237,465
# 13  14                  카카오   50,900     100  +0.20%    100    226,248
# 14  15                 삼성물산  120,600     100  +0.08%    100    223,824
# 15  16                현대모비스  226,000     500  +0.22%  5,000    211,661
# 16  17                 KB금융   51,400     100  -0.19%  5,000    207,405
# 17  18                 신한지주   36,700      50  -0.14%  5,000    189,190
# 18  19                 LG전자  101,800     200  +0.20%  5,000    166,593
# 19  20                 삼성생명   69,400     100  -0.14%    500    138,800
# 20  21              SK이노베이션  136,400     600  +0.44%  5,000    137,294
# 21  22                   LG   82,100     300  -0.36%  5,000    129,144
# 22  23              삼성에스디에스  164,400     700  +0.43%    500    127,209
# 23  24                 한국전력   19,230     100  +0.52%  5,000    123,450
# 24  25                   SK  168,600   1,300  +0.78%    200    123,412
# 25  26               하나금융지주   41,650      50  -0.12%  5,000    121,767
# 26  27                 삼성화재  257,000     500  -0.19%    500    121,753
# 27  28                 KT&G   90,100   1,100  +1.24%  5,000    120,574
# 28  29                카카오뱅크   25,250     150  -0.59%  5,000    120,401
# 29  30              HD현대중공업  133,400     400  -0.30%  5,000    118,423
# 30  31              메리츠금융지주   56,700     700  +1.25%    500    118,060
# 31  32                  HMM   16,290     490  -2.92%  5,000    112,245
# 32  33                SK텔레콤   50,800     200  +0.40%    100    111,167
# 33  34                 고려아연  530,000  12,000  +2.32%  5,000    110,816
# 34  35                 삼성전기  146,600   1,500  +1.03%  5,000    109,501
# 35  36                 크래프톤  212,500   5,500  -2.52%    100    102,771
# 36  37              두산에너빌리티   15,900     290  +1.86%  5,000    101,849
# 37  38               우리금융지주   12,890      20  +0.16%  5,000     96,926
# 38  39             포스코인터내셔널   54,300     600  -1.09%  5,000     95,526
# 39  40                 기업은행   11,840      40  +0.34%  5,000     94,415
# 40  41               에코프로머티  136,500   1,000  -0.73%    500     93,130
# 41  42                  하이브  212,500   3,500  +1.67%    500     88,511
# 42  43                   KT   34,100     500  +1.49%  5,000     87,931
# 43  44                 대한항공   22,600       0   0.00%  5,000     83,218
# 44  45             HD한국조선해양  114,700     200  +0.17%  5,000     81,177
# 45  46                 한화오션   25,900   1,050  -3.90%  5,000     79,347
# 46  47                S-Oil   68,900     200  -0.29%  2,500     77,570
# 47  48               아모레퍼시픽  129,800   2,600  +2.04%    500     75,924
# 48  49  TIGER CD금리투자KIS(합성)   53,430       0   0.00%      0     75,253
# 49  50                삼성중공업    8,160      20  +0.25%  1,000     71,808
#
#         상장주식수  외국인비율        거래량     PER     ROE
# 0   5,969,783  53.61  4,728,607   15.22   17.07
# 1     234,000   4.53     74,428   66.52    5.75
# 2     728,002  52.83  2,047,529   -8.03    3.56
# 3      71,174  10.20     12,029   54.01   11.42
# 4     822,887  72.79    467,953   12.33     NaN
# 5      84,571  26.48    216,233   32.23    6.11
# 6     211,532  32.88    125,227    4.35    9.36
# 7     162,409  47.54    457,576   41.34    3.29
# 8     402,044  38.63    265,152    3.70   14.57
# 9      70,592  43.09    104,302   28.39    6.95
# 10     68,765  45.08     81,138   14.73   12.52
# 11     77,463   5.65    729,567  321.84    4.87
# 12    146,403  20.42     93,346   39.31   13.35
# 13    444,496  26.08    523,557  519.39   13.54
# 14    185,592  19.34     41,878    9.84    7.16
# 15     93,655  38.67     27,872    6.24    6.80
# 16    403,511  72.34    232,498    4.41    9.17
# 17    515,504  60.13    249,386    4.64    9.70
# 18    163,648  29.11    152,762   27.36    6.61
# 19    200,000  16.82     30,909    5.55    5.73
# 20    100,656  21.37     86,815  -55.22    8.49
# 21    157,301  36.27     45,283   12.38    8.48
# 22     77,378  16.18     49,272   15.99   14.23
# 23    641,964  13.92    379,658   -0.89  -46.91
# 24     73,198  22.78     43,658  -15.78    5.13
# 25    292,357  68.93    137,898    3.34   10.06
# 26     47,375  53.44     17,079    7.13    9.70
# 27    133,822  42.23    107,483   16.87   11.00
# 28    476,837  15.51    236,828   35.41    4.68
# 29     88,773   7.29     52,713  -70.43   -6.47
# 30    208,218  16.85     93,430    5.24   30.32
# 31    689,039   9.08  1,204,099    3.76   64.98
# 32    218,833  41.77    170,397    9.84    7.97
# 33     20,909  18.29     24,545   17.72    9.38
# 34     74,694  30.53     86,412   23.14   13.76
# 35     48,363  32.41     34,940   23.47   10.29
# 36    640,561  13.30  1,620,864  -23.77  -11.70
# 37    751,949  37.65    319,886    3.24   11.51
# 38    175,923   6.42    304,082   12.68   15.79
# 39    797,426  14.06    224,257    3.29    9.85
# 40     68,227   0.60    967,687  464.29    6.77
# 41     41,652  20.67     92,871  114.80    1.87
# 42    257,861  42.80    528,380    7.42    7.99
# 43    368,221  16.30    173,623    6.19   21.95
# 44     70,773  25.42     68,383   53.98   -2.22
# 45    306,359   9.96    899,929   -8.06 -117.79
# 46    112,583  76.85     52,190    7.90   27.20
# 47     58,493  27.19     48,491   55.66    2.81
# 48    140,844   0.02     77,543     NaN     NaN
# 49    880,000  19.90  1,327,918  -35.02  -16.08

# %%
lans=['python', 'java']
filt = df['SW특기'].str.lower().isin(lans)
df.loc[filt]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85  Python
# 2번    정대만  북산고  184  40  35   50  55  25    Java
# 7번    황태산  능남고  188  55  65   45  40  35  PYTHON

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.fillna('')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.fillna('없음')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80          없음
# 5번    강백호  북산고  188   15   20   10  35  10          없음
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
import numpy as np

# %%
df['학교'] = np.nan
df
# Out:
#        이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수 NaN  197   90   85  100  95  85      Python
# 2번    정대만 NaN  184   40   35   50  55  25        Java
# 3번    송태섭 NaN  168   80   75   70  80  75  Javascript
# 4번    서태웅 NaN  187   40   60   70  75  80         NaN
# 5번    강백호 NaN  188   15   20   10  35  10         NaN
# 6번    변덕규 NaN  202   80  100   95  85  80           C
# 7번    황태산 NaN  188   55   65   45  40  35      PYTHON
# 8번    윤대협 NaN  190  100   85   90  95  95          C#

# %%
df.fillna('모름')
# Out:
#        이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  모름  197   90   85  100  95  85      Python
# 2번    정대만  모름  184   40   35   50  55  25        Java
# 3번    송태섭  모름  168   80   75   70  80  75  Javascript
# 4번    서태웅  모름  187   40   60   70  75  80          모름
# 5번    강백호  모름  188   15   20   10  35  10          모름
# 6번    변덕규  모름  202   80  100   95  85  80           C
# 7번    황태산  모름  188   55   65   45  40  35      PYTHON
# 8번    윤대협  모름  190  100   85   90  95  95          C#

# %%
df.fillna('모름', inplace=True)
df
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_9344\2398059676.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '모름' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('모름', inplace=True)
#        이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  모름  197   90   85  100  95  85      Python
# 2번    정대만  모름  184   40   35   50  55  25        Java
# 3번    송태섭  모름  168   80   75   70  80  75  Javascript
# 4번    서태웅  모름  187   40   60   70  75  80          모름
# 5번    강백호  모름  188   15   20   10  35  10          모름
# 6번    변덕규  모름  202   80  100   95  85  80           C
# 7번    황태산  모름  188   55   65   45  40  35      PYTHON
# 8번    윤대협  모름  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('score.csv')

# %%
df.fillna('모름', inplace=True)

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df2 = df
df2.dropna(inplace=True)
df2
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df =
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('score.csv', index_col='지원번호')

# %%
df.sort_values(['국어', '영어'], ascending=[False, True])
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN

# %%
df.sort_index(ascending=False)
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 1번    채치수  북산고  197   90   85  100  95  85      Python

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교'].replace({'북산고':'상북고', '능남고':'무슨고'})
# Out:
# 지원번호
# 1번    상북고
# 2번    상북고
# 3번    상북고
# 4번    상북고
# 5번    상북고
# 6번    무슨고
# 7번    무슨고
# 8번    무슨고
# Name: 학교, dtype: object

# %%
df['학교'].replace({'북산고':'상북고'}, inplace=True)

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      Python
# 2번    정대만  상북고  184   40   35   50  55  25        Java
# 3번    송태섭  상북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['SW특기'].str.lower()
# Out:
# 지원번호
# 1번        python
# 2번          java
# 3번    javascript
# 4번           NaN
# 5번           NaN
# 6번             c
# 7번        python
# 8번            c#
# Name: SW특기, dtype: object

# %%
df['SW특기'] = df['SW특기'].str.lower()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      python
# 2번    정대만  상북고  184   40   35   50  55  25        java
# 3번    송태섭  상북고  168   80   75   70  80  75  javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           c
# 7번    황태산  능남고  188   55   65   45  40  35      python
# 8번    윤대협  능남고  190  100   85   90  95  95          c#

# %%
df['SW특기'] = df['SW특기'].str.upper()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      PYTHON
# 2번    정대만  상북고  184   40   35   50  55  25        JAVA
# 3번    송태섭  상북고  168   80   75   70  80  75  JAVASCRIPT
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교'] = df['학교'] + '등학교'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#

# %%
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465

# %%
df['결과'] = 'Fail'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Fail
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Fail
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Fail

# %%
df.loc[df['총합']>=400, '결과'] = 'Pass'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass

# %%
df.drop(columns=['총합'])
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  Pass

# %%
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass

# %%
df.drop(index='4번')
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass

# %%
filt = df['수학'] <80
df[filt].index
# Out:
# Index(['2번', '3번', '4번', '5번', '7번'], dtype='object', name='지원번호')

# %%
df.drop(index=df[filt].index)
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회    SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85  PYTHON  455  Pass
# 6번    변덕규  능남고등학교  202   80  100   95  85  80       C  440  Pass
# 8번    윤대협  능남고등학교  190  100   85   90  95  95      C#  465  Pass

# %%
df.loc['9번'] = ['이정환', '해남고등하고', 184, 90, 90, 90, 90, 90, 'Kotlin', 450, 'Pass'] 
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass
# 9번    이정환  해남고등하고  184   90   90   90  90  90      Kotlin  450  Pass

# %%
df.loc['5번', ['학교', 'SW특기']] = ['능남고등학교', 'C']
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  능남고등학교  188   15   20   10  35  10           C   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass
# 9번    이정환  해남고등하고  184   90   90   90  90  90      Kotlin  450  Pass

# %%
df.loc['4번', 'SW특기'] = 'Python'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        JAVA  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80      Python  325  Fail
# 5번    강백호  능남고등학교  188   15   20   10  35  10           C   90  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass
# 9번    이정환  해남고등하고  184   90   90   90  90  90      Kotlin  450  Pass

# %%
cols = list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '총합', '결과']

# %%
df = df[[cols[-1]] + cols[0:-1]]
df
# Out:
#         결과   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    Pass  채치수  상북고등학교  197   90   85  100  95  85      PYTHON  455
# 2번    Fail  정대만  상북고등학교  184   40   35   50  55  25        JAVA  205
# 3번    Fail  송태섭  상북고등학교  168   80   75   70  80  75  JAVASCRIPT  380
# 4번    Fail  서태웅  상북고등학교  187   40   60   70  75  80      Python  325
# 5번    Fail  강백호  능남고등학교  188   15   20   10  35  10           C   90
# 6번    Pass  변덕규  능남고등학교  202   80  100   95  85  80           C  440
# 7번    Fail  황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240
# 8번    Pass  윤대협  능남고등학교  190  100   85   90  95  95          C#  465
# 9번    Pass  이정환  해남고등하고  184   90   90   90  90  90      Kotlin  450

# %%
df2 = df[['결과', '이름', '학교']]
df2
# Out:
#         결과   이름      학교
# 지원번호
# 1번    Pass  채치수  상북고등학교
# 2번    Fail  정대만  상북고등학교
# 3번    Fail  송태섭  상북고등학교
# 4번    Fail  서태웅  상북고등학교
# 5번    Fail  강백호  능남고등학교
# 6번    Pass  변덕규  능남고등학교
# 7번    Fail  황태산  능남고등학교
# 8번    Pass  윤대협  능남고등학교
# 9번    Pass  이정환  해남고등하고

# %%
df2.columns = ['Result', 'Name', 'School']
df2
# Out:
#      Result Name  School
# 지원번호
# 1번     Pass  채치수  상북고등학교
# 2번     Fail  정대만  상북고등학교
# 3번     Fail  송태섭  상북고등학교
# 4번     Fail  서태웅  상북고등학교
# 5번     Fail  강백호  능남고등학교
# 6번     Pass  변덕규  능남고등학교
# 7번     Fail  황태산  능남고등학교
# 8번     Pass  윤대협  능남고등학교
# 9번     Pass  이정환  해남고등하고
